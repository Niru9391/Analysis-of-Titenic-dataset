# %%
##pip install matplotlib

# %% [markdown]
# <h1> important library</h1>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h1> loading data</h1>

# %%
df= pd.read_csv('Titanic-Dataset.csv')

# %% [markdown]
# <h1> understanding the data</h1>

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <h1> Descriptive analysis</h1>

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Age']>=18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[df['Embarked']=='C']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex']=='female') &(df['Embarked']=='Q')]
# Out:
#      PassengerId  Survived  Pclass  \
# 22            23         1       3
# 28            29         1       3
# 32            33         1       3
# 44            45         1       3
# 47            48         1       3
# 82            83         1       3
# 109          110         1       3
# 156          157         1       3
# 186          187         1       3
# 198          199         1       3
# 208          209         1       3
# 241          242         1       3
# 264          265         0       3
# 274          275         1       3
# 289          290         1       3
# 300          301         1       3
# 303          304         1       2
# 322          323         1       2
# 330          331         1       3
# 358          359         1       3
# 359          360         1       3
# 368          369         1       3
# 412          413         1       1
# 501          502         0       3
# 502          503         0       3
# ...

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# <h1>Cleaning the data</h1>

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
median= df['Age'].median()
median
# Out:
# np.float64(28.0)

# %%
df['Age']=df['Age'].fillna(median)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mode_emabrked=df['Embarked'].mode()[0]
mode_emabrked
# Out:
# 'S'

# %%
df['Embarked']=df['Embarked'].fillna(mode_emabrked)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# <h1>one hot encoding</h1>

# %%
df['New_cabin']=df['Cabin'].notna().astype(int)

# %%
df['New_cabin']
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: New_cabin, Length: 891, dtype: int64

# %% [markdown]
# <h1>Drop original column</h1>

# %%
df.drop('Cabin', axis=1,inplace=True)

# %%
df['New_cabin'].value_counts()
# Out:
# New_cabin
# 0    687
# 1    204
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# New_cabin      0
# dtype: int64

# %% [markdown]
# <h1>Univariet analysis</h1>

# %%
## set up the figure for the plot
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Univariate Analysis of Categorical Features', fontsize=16)

# Count plots
sns.countplot(ax=axes[0, 0], x='Survived', data=df).set_title('Survival Distribution')
sns.countplot(ax=axes[0, 1], x='Pclass', data=df).set_title('Passenger Class Distribution')
sns.countplot(ax=axes[0, 2], x='Sex', data=df).set_title('Gender Distribution')
sns.countplot(ax=axes[1, 0], x='Embarked', data=df).set_title('Port of Embarkation')
sns.countplot(ax=axes[1, 1], x='SibSp', data=df).set_title('Siblings Aboard')
sns.countplot(ax=axes[1, 2], x='Parch', data=df).set_title('Parents Aboard')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# <h1>Bivariate Analysis</h1>

# %%
# Set up the figure
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Bivariate Analysis of Categorical Features with Survival', fontsize=16)

# Plot 1: Survival vs Gender
sns.countplot(ax=axes[0, 0], x='Sex', hue='Survived', data=df)
axes[0, 0].set_title('Survival by Gender')

# Plot 2: Survival vs Passenger Class
sns.countplot(ax=axes[0, 1], x='Pclass', hue='Survived', data=df)
axes[0, 1].set_title('Survival by Passenger Class')

# Plot 3: Survival vs Embarkation Port
sns.countplot(ax=axes[0, 2], x='Embarked', hue='Survived', data=df)
axes[0, 2].set_title('Survival by Embarkation Port')

# Plot 4: Survival vs Number of Siblings/Spouses
sns.countplot(ax=axes[1, 0], x='SibSp', hue='Survived', data=df)
axes[1, 0].set_title('Survival by Siblings/Spouses Aboard')

# Plot 5: Survival vs Number of Parents/Children
sns.countplot(ax=axes[1, 1], x='Parch', hue='Survived', data=df)
axes[1, 1].set_title('Survival by Parents/Children Aboard')

# Plot 6: Survival vs Fare (continuous variable)
sns.boxplot(ax=axes[1, 2], x='Survived', y='Fare', data=df)
axes[1, 2].set_title('Survival vs Fare')

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
g = sns.FacetGrid(df, col='Survived', height=5, aspect=1.2)

# Map a histogram (or KDE plot) of Age onto each facet
g.map(sns.histplot, 'Age', bins=30, kde=True, color='skyblue')

# Add titles and labels
g.set_axis_labels('Age', 'Count')
g.set_titles(col_template='Survived = {col_name}')

# Add overall title
plt.subplots_adjust(top=0.8)
g.fig.suptitle('Age Distribution by Survival')

plt.show()

# %%
## create a familySize column
df['FamilySize'] = df['SibSp']+df['Parch']+1

# %%
df['IsAlone']=0
df.loc[df['FamilySize']==1]=1
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            1         1       1
# 3            4         1       1
# 4            1         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                                  1       1   1.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                                                  1       1   1.0      1
#
#    Parch     Ticket     Fare Embarked  New_cabin  FamilySize  IsAlone
# 0      0  A/5 21171   7.2500        S          0           2        0
# 1      0   PC 17599  71.2833        C          1           2        0
# 2      1          1   1.0000        1          1           1        1
# ...

# %%
df['Title'] = df['Name'].str.extract(r'([A-Za-z]+)\.', expand=False)

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr        120
# Mrs       105
# Miss       82
# Master     40
# Dr          2
# Rev         2
# Lady        1
# Sir         1
# Capt        1
# Name: count, dtype: int64

# %%
df['Title'] = df['Title'].replace({
    'Miss': 'Miss',
    'Lady': 'Miss',
    'Master': 'Mr',
    'Dr': 'Mr',
    'Rev': 'Mr',
    'Sir': 'Mr',
    'Capt': 'Mr'
})

# %%
df['Title'].value_counts()
# Out:
# Title
# Mrs    188
# Mr     166
# Name: count, dtype: int64

# %% [markdown]
# <h1>Correlation Analysis</h1>

# %%
corr_matrix = df.corr(numeric_only=True)

# Display the correlation matrix
print(corr_matrix)

# Visualize it with a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# Optional: Correlation with target variable (if available)
if 'Survived' in df.columns:
    print("\nCorrelation with Survived column:")
    print(corr_matrix['Survived'].sort_values(ascending=False))
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.423788  0.536548  0.648563  0.106224  0.014772
# Survived       -0.423788  1.000000 -0.649967 -0.514999 -0.333067 -0.037762
# Pclass          0.536548 -0.649967  1.000000  0.420298  0.331920  0.105314
# Age             0.648563 -0.514999  0.420298  1.000000  0.002344 -0.097862
# SibSp           0.106224 -0.333067  0.331920  0.002344  1.000000  0.105339
# Parch           0.014772 -0.037762  0.105314 -0.097862  0.105339  1.000000
# Fare            0.461749 -0.226169  0.050087  0.547509  0.096291  0.067488
# New_cabin      -0.584745  0.621326 -0.897573 -0.500477 -0.280996 -0.041655
# FamilySize      0.544115 -0.572338  0.669386  0.448395  0.709114  0.447277
# IsAlone        -0.788140  0.608903 -0.724689 -0.802092 -0.170585  0.029564
#
#                  Fare  New_cabin  FamilySize   IsAlone
# PassengerId  0.461749  -0.584745    0.544115 -0.788140
# ...

# %% [markdown]
# <h1>Negative correlation meaning means opposite behaviour and  positive correlation between same behaviour</h1>

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/ASUS/21 days project of  ML/.git/

# %%
# !git config --global user.name "Niranjan kumar"
# !git config --global user.email "Niranjanyadav9655@gmail.com"
